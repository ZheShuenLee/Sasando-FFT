# %% [markdown]
# # Sasando Acoustic Replication: Write-up

# %% [markdown]
# ## Abstract

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Theory

# %% [markdown]
# ## Methods

# %% [markdown]
# ## Results

# %% [markdown]
# ## Discussion & Conclusion
